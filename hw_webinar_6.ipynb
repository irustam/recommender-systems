# %% [markdown]
# # Вебинар 6. Двухуровневые модели рекомендаций

# %% [markdown]
# Код для src, utils, metrics вы можете скачать из [этого](https://github.com/geangohn/recsys-tutorial) github репозитория

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_columns', 500)

# Для работы с матрицами
from scipy.sparse import csr_matrix

# Матричная факторизация
from implicit import als

# Модель второго уровня
from lightgbm import LGBMClassifier

import os, sys
module_path = os.path.abspath(os.path.join(os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

# Написанные нами функции
from metrics import precision_at_k, recall_at_k
from src.utils import prefilter_items
from src.recommenders import MainRecommender

# %%
data = pd.read_csv('./raw_data/retail_train.csv')

# Важна схема обучения и валидации!
# -- давние покупки -- | -- 6 недель -- | -- 3 недель -- 
# подобрать размер 2-ого датасета (6 недель) --> learning curve (зависимость метрики recall@k от размера датасета)
val_lvl_1_size_weeks = 6
val_lvl_2_size_weeks = 3

data_train_lvl_1 = data[data['week_no'] < data['week_no'].max() - (val_lvl_1_size_weeks + val_lvl_2_size_weeks)]
data_val_lvl_1 = data[(data['week_no'] >= data['week_no'].max() - (val_lvl_1_size_weeks + val_lvl_2_size_weeks)) &
                      (data['week_no'] < data['week_no'].max() - (val_lvl_2_size_weeks))]

data_train_lvl_2 = data_val_lvl_1.copy()  # Для наглядности. Далее мы добавим изменения, и они будут отличаться
data_val_lvl_2 = data[data['week_no'] >= data['week_no'].max() - val_lvl_2_size_weeks]

data_train_lvl_1.head(2)
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     2375  26984851472    1  1004906         1         1.39       364
# 1     2375  26984851472    1  1033142         1         0.82       364
#
#    retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 0         -0.6        1631        1          0.0                0.0
# 1          0.0        1631        1          0.0                0.0

# %%
#все покупки
data['week_no'].max(), data['week_no'].min()
# Out:
# (95, 1)

# %%
#давние покупки
data_train_lvl_1['week_no'].max(), data_train_lvl_1['week_no'].min()
# Out:
# (85, 1)

# %%
#валидационные 6 недель для первого уровня
data_val_lvl_1['week_no'].max(), data_val_lvl_1['week_no'].min()
# Out:
# (91, 86)

# %%
#6 недель для второго уровня
data_train_lvl_2['week_no'].max(), data_train_lvl_2['week_no'].min()
# Out:
# (91, 86)

# %%
#валидационные 3 недели для первого уровня
data_val_lvl_2['week_no'].max(), data_val_lvl_2['week_no'].min()
# Out:
# (95, 92)

# %%
#популярность товаров считается как кол-во уников, купивших товар
popularity = data_train_lvl_1.groupby('item_id')['user_id'].nunique().reset_index()

# %%
#доля товаров - отношение кол-ва уников, купивших товар, к кол-ву всего уников
popularity['share'] = popularity['user_id']/ data_train_lvl_1['user_id'].nunique()

# %%
#товар, который покупали чаще всего
popularity.loc[popularity['share']==popularity['share'].max()]
# Out:
#        item_id  user_id     share
# 34192  1082185     1995  0.798639

# %%
#всего уникальных товаров в датасете data_train_lvl_1 
popularity.shape
# Out:
# (83685, 3)

# %%
#товары, которые покупали менее 2% юзеров
popularity[popularity['share'] < 0.02]
# Out:
#         item_id  user_id     share
# 0         25671        3  0.001201
# 1         26081        1  0.000400
# 2         26093        1  0.000400
# 3         26190        1  0.000400
# 4         26355        1  0.000400
# ...         ...      ...       ...
# 83680  17179426        1  0.000400
# 83681  17208239        1  0.000400
# 83682  17208470        1  0.000400
# 83683  17209402        3  0.001201
# 83684  17209483        1  0.000400
#
# [77996 rows x 3 columns]

# %%
#товары, которые покупали более 2% юзеров
popularity[popularity['share'] > 0.2]
# Out:
#         item_id  user_id     share
# 6205     826249     1236  0.494796
# 6952     833025      752  0.301041
# 7123     834484      805  0.322258
# 7763     840361     1234  0.493995
# 8180     844165      635  0.254203
# ...         ...      ...       ...
# 59365   8090521      531  0.212570
# 59369   8090537      538  0.215372
# 63920   9526410      657  0.263010
# 64241   9527290      571  0.228583
# 75067  12810393      556  0.222578
#
# [101 rows x 3 columns]

# %%
item_features = pd.read_csv('./raw_data/product.csv')
user_features = pd.read_csv('./raw_data/hh_demographic.csv')

# column processing
item_features.columns = [col.lower() for col in item_features.columns]
user_features.columns = [col.lower() for col in user_features.columns]

item_features.rename(columns={'product_id': 'item_id'}, inplace=True)
user_features.rename(columns={'household_key': 'user_id'}, inplace=True)

# %%
#всего уникальных товаров в датасете data_train_lvl_1 
n_items_before = data_train_lvl_1['item_id'].nunique()

# %%
#префильтрация товаров
data_train_lvl_1 = prefilter_items(data_train_lvl_1, item_features=item_features, take_n_popular=5000)

# %%
n_items_after = data_train_lvl_1['item_id'].nunique()
print('Decreased # items from {} to {}'.format(n_items_before, n_items_after))
# Out:
# Decreased # items from 83685 to 5001

# %%
recommender = MainRecommender(data_train_lvl_1)
# Out:
# WARNING:root:Intel MKL BLAS detected. Its highly recommend to set the environment variable 'export MKL_NUM_THREADS=1' to disable its internal multithreading
# weighting done

# %%
recommender.get_als_recommendations(200000375, N=200)
# Out:
# [999999,
#  1029743,
#  1106523,
#  5569230,
#  916122,
#  844179,
#  1044078,
#  1126899,
#  1070820,
#  1127831,
#  866211,
#  8090521,
#  878996,
#  8090537,
#  5569471,
#  1004906,
#  854852,
#  899624,
#  986912,
#  933835,
#  1075368,
#  1081177,
#  6034857,
#  5585510,
#  965267,
#  834117,
#  940947,
#  983584,
#  12810393,
#  913210,
#  874972,
#  5569845,
#  5568378,
#  999858,
#  908318,
#  985999,
#  901062,
#  1040807,
#  1018740,
#  951412,
#  1101010,
#  1105488,
#  1037840,
#  880150,
#  1043751,
#  857503,
#  1122358,
#  1132771,
#  823704,
#  854405,
#  909714,
#  993638,
#  930118,
#  839419,
#  971922,
#  910032,
#  863447,
#  835098,
#  865456,
#  976199,
#  12301109,
#  1070702,
#  5569374,
#  8090532,
#  872137,
#  883003,
#  1023720,
#  1012587,
#  1000753,
#  893018,
#  1024306,
#  897954,
#  1042438,
#  907631,
#  5568729,
#  1068719,
#  1137775,
#  1087102,
#  944534,
#  1020581,
#  999270,
#  832678,
#  838186,
#  1138443,
#  999104,
#  1112238,
#  1050851,
#  902172,
#  965766,
#  12301100,
#  952163,
#  957951,
#  8090509,
#  852856,
#  885863,
#  1056509,
#  845307,
#  1062002,
#  944836,
#  819978,
#  957736,
#  999779,
#  1027168,
#  1051323,
#  8065410,
#  1026118,
#  849202,
#  944137,
#  1051211,
#  831628,
#  1046545,
#  12301405,
#  1038663,
#  871756,
#  1022097,
#  926905,
#  865528,
#  896613,
#  935317,
#  5569327,
#  995965,
#  1006184,
#  1082185,
#  948670,
#  8090440,
#  9835509,
#  6442594,
#  8090536,
#  892531,
#  823990,
#  998119,
#  1128016,
#  861279,
#  8177622,
#  866871,
#  1042907,
#  933067,
#  1013928,
#  990797,
#  12302069,
#  1022254,
#  999714,
#  7139529,
#  1055504,
#  5568489,
#  1042544,
#  1068292,
#  865174,
#  850102,
#  1075214,
#  921504,
#  828106,
#  1000237,
#  904129,
#  909268,
#  823721,
#  9245106,
#  871611,
#  848029,
#  1025611,
#  1137346,
#  948650,
#  896862,
#  1115175,
#  1062128,
#  885290,
#  1016800,
#  1002771,
#  961979,
#  910673,
#  1055425,
#  6602697,
#  880427,
#  937292,
#  883932,
#  5591170,
#  1097001,
#  1070272,
#  1135258,
#  1074754,
#  866755,
#  910473,
#  968072,
#  925862,
#  10344585,
#  825343,
#  991223,
#  859427,
#  1127179,
#  1074333,
#  865705,
#  871061,
#  1067695,
#  960732,
#  995478,
#  10149640,
#  965842,
#  825994,
#  12262778,
#  854754]

# %%
recommender.get_own_recommendations(2000000375, N=200)
# Out:
# [999999,
#  1029743,
#  1106523,
#  5569230,
#  916122,
#  844179,
#  1044078,
#  1126899,
#  1070820,
#  1127831,
#  866211,
#  8090521,
#  878996,
#  8090537,
#  5569471,
#  1004906,
#  854852,
#  899624,
#  986912,
#  933835,
#  1075368,
#  1081177,
#  6034857,
#  5585510,
#  965267,
#  834117,
#  940947,
#  983584,
#  12810393,
#  913210,
#  874972,
#  5569845,
#  5568378,
#  999858,
#  908318,
#  985999,
#  901062,
#  1040807,
#  1018740,
#  951412,
#  1101010,
#  1105488,
#  1037840,
#  880150,
#  1043751,
#  857503,
#  1122358,
#  1132771,
#  823704,
#  854405,
#  909714,
#  993638,
#  930118,
#  839419,
#  971922,
#  910032,
#  863447,
#  835098,
#  865456,
#  976199,
#  12301109,
#  1070702,
#  5569374,
#  8090532,
#  872137,
#  883003,
#  1023720,
#  1012587,
#  1000753,
#  893018,
#  1024306,
#  897954,
#  1042438,
#  907631,
#  5568729,
#  1068719,
#  1137775,
#  1087102,
#  944534,
#  1020581,
#  999270,
#  832678,
#  838186,
#  1138443,
#  999104,
#  1112238,
#  1050851,
#  902172,
#  965766,
#  12301100,
#  952163,
#  957951,
#  8090509,
#  852856,
#  885863,
#  1056509,
#  845307,
#  1062002,
#  944836,
#  819978,
#  957736,
#  999779,
#  1027168,
#  1051323,
#  8065410,
#  1026118,
#  849202,
#  944137,
#  1051211,
#  831628,
#  1046545,
#  12301405,
#  1038663,
#  871756,
#  1022097,
#  926905,
#  865528,
#  896613,
#  935317,
#  5569327,
#  995965,
#  1006184,
#  1082185,
#  948670,
#  8090440,
#  9835509,
#  6442594,
#  8090536,
#  892531,
#  823990,
#  998119,
#  1128016,
#  861279,
#  8177622,
#  866871,
#  1042907,
#  933067,
#  1013928,
#  990797,
#  12302069,
#  1022254,
#  999714,
#  7139529,
#  1055504,
#  5568489,
#  1042544,
#  1068292,
#  865174,
#  850102,
#  1075214,
#  921504,
#  828106,
#  1000237,
#  904129,
#  909268,
#  823721,
#  9245106,
#  871611,
#  848029,
#  1025611,
#  1137346,
#  948650,
#  896862,
#  1115175,
#  1062128,
#  885290,
#  1016800,
#  1002771,
#  961979,
#  910673,
#  1055425,
#  6602697,
#  880427,
#  937292,
#  883932,
#  5591170,
#  1097001,
#  1070272,
#  1135258,
#  1074754,
#  866755,
#  910473,
#  968072,
#  925862,
#  10344585,
#  825343,
#  991223,
#  859427,
#  1127179,
#  1074333,
#  865705,
#  871061,
#  1067695,
#  960732,
#  995478,
#  10149640,
#  965842,
#  825994,
#  12262778,
#  854754]

# %%
recommender.get_similar_items_recommendation(20000000000000375, N=200)
# Out:
# [999999,
#  1029743,
#  1106523,
#  5569230,
#  916122,
#  844179,
#  1044078,
#  1126899,
#  1070820,
#  1127831,
#  866211,
#  8090521,
#  878996,
#  8090537,
#  5569471,
#  1004906,
#  854852,
#  899624,
#  986912,
#  933835,
#  1075368,
#  1081177,
#  6034857,
#  5585510,
#  965267,
#  834117,
#  940947,
#  983584,
#  12810393,
#  913210,
#  874972,
#  5569845,
#  5568378,
#  999858,
#  908318,
#  985999,
#  901062,
#  1040807,
#  1018740,
#  951412,
#  1101010,
#  1105488,
#  1037840,
#  880150,
#  1043751,
#  857503,
#  1122358,
#  1132771,
#  823704,
#  854405,
#  909714,
#  993638,
#  930118,
#  839419,
#  971922,
#  910032,
#  863447,
#  835098,
#  865456,
#  976199,
#  12301109,
#  1070702,
#  5569374,
#  8090532,
#  872137,
#  883003,
#  1023720,
#  1012587,
#  1000753,
#  893018,
#  1024306,
#  897954,
#  1042438,
#  907631,
#  5568729,
#  1068719,
#  1137775,
#  1087102,
#  944534,
#  1020581,
#  999270,
#  832678,
#  838186,
#  1138443,
#  999104,
#  1112238,
#  1050851,
#  902172,
#  965766,
#  12301100,
#  952163,
#  957951,
#  8090509,
#  852856,
#  885863,
#  1056509,
#  845307,
#  1062002,
#  944836,
#  819978,
#  957736,
#  999779,
#  1027168,
#  1051323,
#  8065410,
#  1026118,
#  849202,
#  944137,
#  1051211,
#  831628,
#  1046545,
#  12301405,
#  1038663,
#  871756,
#  1022097,
#  926905,
#  865528,
#  896613,
#  935317,
#  5569327,
#  995965,
#  1006184,
#  1082185,
#  948670,
#  8090440,
#  9835509,
#  6442594,
#  8090536,
#  892531,
#  823990,
#  998119,
#  1128016,
#  861279,
#  8177622,
#  866871,
#  1042907,
#  933067,
#  1013928,
#  990797,
#  12302069,
#  1022254,
#  999714,
#  7139529,
#  1055504,
#  5568489,
#  1042544,
#  1068292,
#  865174,
#  850102,
#  1075214,
#  921504,
#  828106,
#  1000237,
#  904129,
#  909268,
#  823721,
#  9245106,
#  871611,
#  848029,
#  1025611,
#  1137346,
#  948650,
#  896862,
#  1115175,
#  1062128,
#  885290,
#  1016800,
#  1002771,
#  961979,
#  910673,
#  1055425,
#  6602697,
#  880427,
#  937292,
#  883932,
#  5591170,
#  1097001,
#  1070272,
#  1135258,
#  1074754,
#  866755,
#  910473,
#  968072,
#  925862,
#  10344585,
#  825343,
#  991223,
#  859427,
#  1127179,
#  1074333,
#  865705,
#  871061,
#  1067695,
#  960732,
#  995478,
#  10149640,
#  965842,
#  825994,
#  12262778,
#  854754]

# %%
recommender.get_similar_users_recommendation(20000375, N=200)
# Out:
# [999999,
#  1029743,
#  1106523,
#  5569230,
#  916122,
#  844179,
#  1044078,
#  1126899,
#  1070820,
#  1127831,
#  866211,
#  8090521,
#  878996,
#  8090537,
#  5569471,
#  1004906,
#  854852,
#  899624,
#  986912,
#  933835,
#  1075368,
#  1081177,
#  6034857,
#  5585510,
#  965267,
#  834117,
#  940947,
#  983584,
#  12810393,
#  913210,
#  874972,
#  5569845,
#  5568378,
#  999858,
#  908318,
#  985999,
#  901062,
#  1040807,
#  1018740,
#  951412,
#  1101010,
#  1105488,
#  1037840,
#  880150,
#  1043751,
#  857503,
#  1122358,
#  1132771,
#  823704,
#  854405,
#  909714,
#  993638,
#  930118,
#  839419,
#  971922,
#  910032,
#  863447,
#  835098,
#  865456,
#  976199,
#  12301109,
#  1070702,
#  5569374,
#  8090532,
#  872137,
#  883003,
#  1023720,
#  1012587,
#  1000753,
#  893018,
#  1024306,
#  897954,
#  1042438,
#  907631,
#  5568729,
#  1068719,
#  1137775,
#  1087102,
#  944534,
#  1020581,
#  999270,
#  832678,
#  838186,
#  1138443,
#  999104,
#  1112238,
#  1050851,
#  902172,
#  965766,
#  12301100,
#  952163,
#  957951,
#  8090509,
#  852856,
#  885863,
#  1056509,
#  845307,
#  1062002,
#  944836,
#  819978,
#  957736,
#  999779,
#  1027168,
#  1051323,
#  8065410,
#  1026118,
#  849202,
#  944137,
#  1051211,
#  831628,
#  1046545,
#  12301405,
#  1038663,
#  871756,
#  1022097,
#  926905,
#  865528,
#  896613,
#  935317,
#  5569327,
#  995965,
#  1006184,
#  1082185,
#  948670,
#  8090440,
#  9835509,
#  6442594,
#  8090536,
#  892531,
#  823990,
#  998119,
#  1128016,
#  861279,
#  8177622,
#  866871,
#  1042907,
#  933067,
#  1013928,
#  990797,
#  12302069,
#  1022254,
#  999714,
#  7139529,
#  1055504,
#  5568489,
#  1042544,
#  1068292,
#  865174,
#  850102,
#  1075214,
#  921504,
#  828106,
#  1000237,
#  904129,
#  909268,
#  823721,
#  9245106,
#  871611,
#  848029,
#  1025611,
#  1137346,
#  948650,
#  896862,
#  1115175,
#  1062128,
#  885290,
#  1016800,
#  1002771,
#  961979,
#  910673,
#  1055425,
#  6602697,
#  880427,
#  937292,
#  883932,
#  5591170,
#  1097001,
#  1070272,
#  1135258,
#  1074754,
#  866755,
#  910473,
#  968072,
#  925862,
#  10344585,
#  825343,
#  991223,
#  859427,
#  1127179,
#  1074333,
#  865705,
#  871061,
#  1067695,
#  960732,
#  995478,
#  10149640,
#  965842,
#  825994,
#  12262778,
#  854754]

# %% [markdown]
# ### Задание 1
#
# A) Попробуйте различные варианты генерации кандидатов. Какие из них дают наибольший recall@k ?
# - Пока пробуем отобрать 200 кандидатов (k=200)
# - Качество измеряем на data_val_lvl_1: следующие 6 недель после трейна
#
# Дают ли own recommendtions + top-popular лучший recall?
#
# B)* Как зависит recall@k от k? Постройте для одной схемы генерации кандидатов эту зависимость для k = {20, 50, 100, 200, 500}
# C)* Исходя из прошлого вопроса, как вы думаете, какое значение k является наиболее разумным?

# %%
result_lvl_1 = data_val_lvl_1.groupby('user_id')['item_id'].unique().reset_index()
result_lvl_1.columns=['user_id', 'actual']
result_lvl_1.head(2)
# Out:
#    user_id                                             actual
# 0        1  [853529, 865456, 867607, 872137, 874905, 87524...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...

# %% [markdown]
# a) Попробуйте различные варианты генерации кандидатов. Какие из них дают наибольший recall@k ?

# %%
# %%time
result_lvl_1['get_als_recommendations'] = result_lvl_1['user_id'].apply(lambda x: 
                                                                   np.array(recommender.get_als_recommendations(x, N=200)))
result_lvl_1.head(2)
# Out:
# Wall time: 22.6 s
#    user_id                                             actual  \
# 0        1  [853529, 865456, 867607, 872137, 874905, 87524...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...
#
#                              get_als_recommendations
# 0  [959455, 865026, 1077133, 10455984, 9677939, 9...
# 1  [916122, 1127831, 9858819, 1004906, 9526159, 8...

# %%
# %%time
result_lvl_1['get_own_recommendations'] = result_lvl_1['user_id'].apply(lambda x: 
                                                                   np.array(recommender.get_own_recommendations(x, N=200)))
result_lvl_1.head(2)
# Out:
# Wall time: 8.29 s
#    user_id                                             actual  \
# 0        1  [853529, 865456, 867607, 872137, 874905, 87524...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...
#
#                              get_als_recommendations  \
# 0  [959455, 865026, 1077133, 10455984, 9677939, 9...
# 1  [916122, 1127831, 9858819, 1004906, 9526159, 8...
#
#                              get_own_recommendations
# 0  [1029743, 1004906, 12810393, 8090521, 6034857,...
# 1  [916122, 1106523, 5569230, 1127831, 899624, 80...

# %%
# %%time
result_lvl_1['get_similar_items_recommendation'] = result_lvl_1['user_id'].apply(lambda x: 
                                                                   np.array(recommender.get_similar_items_recommendation(x, N=200)))
result_lvl_1.head(2)
# Out:
# Wall time: 30.8 s
#    user_id                                             actual  \
# 0        1  [853529, 865456, 867607, 872137, 874905, 87524...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...
#
#                              get_als_recommendations  \
# 0  [959455, 865026, 1077133, 10455984, 9677939, 9...
# 1  [916122, 1127831, 9858819, 1004906, 9526159, 8...
#
#                              get_own_recommendations  \
# 0  [1029743, 1004906, 12810393, 8090521, 6034857,...
# 1  [916122, 1106523, 5569230, 1127831, 899624, 80...
#
#                     get_similar_items_recommendation
# 0  [1076056, 825665, 1007512, 974177, 904833, 896...
# 1  [1076056, 8090509, 5569845, 8090537, 985999, 8...

# %%
# %%time
result_lvl_1['get_similar_users_recommendation'] = result_lvl_1['user_id'].apply(lambda x: 
                                                                   np.array(recommender.get_similar_users_recommendation(x, N=200)))
result_lvl_1.head(2)
# Out:
# Wall time: 26min 23s
#    user_id                                             actual  \
# 0        1  [853529, 865456, 867607, 872137, 874905, 87524...
# 1        2  [15830248, 838136, 839656, 861272, 866211, 870...
#
#                              get_als_recommendations  \
# 0  [8090560, 962615, 8090541, 10356272, 1120261, ...
# 1  [1127831, 866211, 967041, 910032, 1029743, 556...
#
#                              get_own_recommendations  \
# 0  [1029743, 1004906, 12810393, 8090521, 6034857,...
# 1  [916122, 1106523, 5569230, 1127831, 899624, 80...
#
#                     get_similar_items_recommendation  \
# 0  [944486, 882013, 5582712, 990656, 9419443, 103...
# 1  [944486, 8090509, 5569845, 1035207, 985999, 84...
#
#                     get_similar_users_recommendation
# 0  [1004906, 999999, 1126899, 1029743, 1127831, 1...
# 1  [1022254, 1029743, 844179, 1029743, 916122, 10...

# %%
# %%time
print('precision_at_k', 'get_als_recommendations',
      result_lvl_1.apply(lambda row: precision_at_k(row['get_als_recommendations'], row['actual']), axis=1).mean())
print('precision_at_k', 'get_own_recommendations',
      result_lvl_1.apply(lambda row: precision_at_k(row['get_own_recommendations'], row['actual']), axis=1).mean())
print('precision_at_k', 'get_similar_items_recommendation',
      result_lvl_1.apply(lambda row: precision_at_k(row['get_similar_items_recommendation'], row['actual']), axis=1).mean())
print('precision_at_k', 'get_similar_users_recommendation',
      result_lvl_1.apply(lambda row: precision_at_k(row['get_similar_users_recommendation'], row['actual']), axis=1).mean())
# Out:
# precision_at_k get_als_recommendations 0.09953574744661027
# precision_at_k get_own_recommendations 0.17901578458681228
# precision_at_k get_similar_items_recommendation 0.04168987929433637
# precision_at_k get_similar_users_recommendation 0.07706592386258108
# Wall time: 535 ms

# %%
# %%time
print('recall_at_k', 'get_als_recommendations', 
      result_lvl_1.apply(lambda row: recall_at_k(row['get_als_recommendations'], row['actual']), axis=1).mean())
print('recall_at_k', 'get_own_recommendations',
      result_lvl_1.apply(lambda row: recall_at_k(row['get_own_recommendations'], row['actual']), axis=1).mean())
print('recall_at_k', 'get_similar_items_recommendation',
      result_lvl_1.apply(lambda row: recall_at_k(row['get_similar_items_recommendation'], row['actual']), axis=1).mean())
print('recall_at_k', 'get_similar_users_recommendation', 
      result_lvl_1.apply(lambda row: recall_at_k(row['get_similar_users_recommendation'], row['actual']), axis=1).mean())
# Out:
# recall_at_k get_als_recommendations 0.009075426937001743
# recall_at_k get_own_recommendations 0.020395456287105648
# recall_at_k get_similar_items_recommendation 0.004816114666616715
# recall_at_k get_similar_users_recommendation 0.00853458216425187
# Wall time: 506 ms

# %% [markdown]
# own recommendtions + top-popular дают лучший recall и precision_at_k

# %% [markdown]
# B)* Как зависит recall@k от k? Постройте для одной схемы генерации кандидатов эту зависимость для k = {20, 50, 100, 200, 500}

# %%
k = [20, 50, 100, 200, 500]
print('recall_at_k', 'get_own_recommendations')
for i in k:
    print(f'k={i}',
      result_lvl_1.apply(lambda row: recall_at_k(row['get_own_recommendations'], row['actual'], i), axis=1).mean())
# Out:
# recall_at_k get_own_recommendations
# k=20 0.04225947870645031
# k=50 0.06754947411543526
# k=100 0.09010043577407759
# k=200 0.12090688172022042
# k=500 0.12090688172022042

# %% [markdown]
# Чем больше k, тем выше recall@k. В моем примере при recall@200 и recall@500 равны, потому что у меня всего 200 предсказаний на пользователя в таблице

# %% [markdown]
# C)* Исходя из прошлого вопроса, как вы думаете, какое значение k является наиболее разумным?

# %% [markdown]
# Поскольку, в большинстве случаев пользователю показываются небольшое кол-во рекомендаций, то лучше брать небольшие значения - например, 20. Редко пользователи просматривают больше.

# %% [markdown]
# ### Задание 2.
#
# Обучите модель 2-ого уровня, при этом:
#     - Добавьте минимум по 2 фичи для юзера, товара и пары юзер-товар
#     - Измерьте отдельно precision@5 модели 1-ого уровня и двухуровневой модели на data_val_lvl_2
#     - Вырос ли precision@5 при использовании двухуровневой модели?

# %%
# создаем датасет с униками из data_train_lvl_2
users_lvl_2 = pd.DataFrame(data_train_lvl_2['user_id'].unique())
users_lvl_2.columns = ['user_id']
users_lvl_2['user_id'].nunique()
# Out:
# 2154

# %%
# Пока только warm start (убираем тех из users_lvl_2, кого нет в датасете data_train_lvl_1)
train_users = data_train_lvl_1['user_id'].unique()
users_lvl_2 = users_lvl_2[users_lvl_2['user_id'].isin(train_users)]

# %%
# получаем собственные покупки пользователей датасета data_train_lvl_2 через предсказания ItemItemRecommender
users_lvl_2['candidates'] = users_lvl_2['user_id'].apply(lambda x: recommender.get_own_recommendations(x, N=200))
users_lvl_2.head(2)
# Out:
#    user_id                                         candidates
# 0     2070  [1029743, 916122, 1044078, 1106523, 5569230, 1...
# 1     2021  [844179, 1044078, 5569230, 1004906, 899624, 10...

# %%
# переводим колонку с собственными покупками в строки, чтобы было соответствие user_id - item_id
s = users_lvl_2.apply(lambda x: pd.Series(x['candidates']), axis=1).stack().reset_index(level=1, drop=True)
s.name = 'item_id'

users_lvl_2 = users_lvl_2.drop('candidates', axis=1).join(s)
users_lvl_2['drop'] = 1  # фиктивная переменная

users_lvl_2.head(4)
# Out:
#    user_id  item_id  drop
# 0     2070  1029743     1
# 0     2070   916122     1
# 0     2070  1044078     1
# 0     2070  1106523     1

# %%
#Всего строк в таблице собственных покупок и всего уников
users_lvl_2.shape[0], users_lvl_2['user_id'].nunique()
# Out:
# (430200, 2151)

# %%
data_train_lvl_2['item_id'].nunique()
# Out:
# 27649

# %%
targets_lvl_2['item_id'].nunique()
# Out:
# 3052

# %%
users_lvl_2['item_id'].nunique()
# Out:
# 3053

# %% [markdown]
# ### Генерация фичей:

# %% [markdown]
# #### Фичи для пользователей

# %%
data.head(2)
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     2375  26984851472    1  1004906         1         1.39       364
# 1     2375  26984851472    1  1033142         1         0.82       364
#
#    retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc  \
# 0         -0.6        1631        1          0.0                0.0
# 1          0.0        1631        1          0.0                0.0
#
#    user_id_orders timeperiod_order
# 0               5            night
# 1               5            night

# %%
#Вычисляем кол-во заказов на пользователя, кол-во уникальных товаров в заказах, сумму заказов на пользователя и т.д.
users_orders_df = data.groupby('user_id', as_index=False).agg({
    'basket_id': 'nunique',
    'item_id': 'nunique',
    'retail_disc': 'sum',
    'coupon_disc': 'sum',
    'coupon_match_disc': 'sum',
    'sales_value': 'sum'}).rename(columns={'basket_id': 'orders_per_user', 
                                           'item_id': 'uniques_items', 
                                           'sales_value': 'value_per_user'})
users_orders_df.head(2)
# Out:
#    user_id  orders_per_user  uniques_items  retail_disc  coupon_disc  \
# 0        1               79            627      -653.47       -78.96
# 1        2               44            510      -318.96        -9.00
#
#    coupon_match_disc  value_per_user
# 0             -24.75         3959.91
# 1               0.00         1823.45

# %%
#Вычисляем среднюю сумму заказа
users_orders_df['av_order_value'] = users_orders_df.value_per_user / users_orders_df.orders_per_user

#Вычисляем среднее кол-во уникальных товаров в заказе
users_orders_df['av_unique_items_per_order'] = users_orders_df.uniques_items / users_orders_df.orders_per_user
users_orders_df.head(2)
# Out:
#    user_id  orders_per_user  uniques_items  retail_disc  coupon_disc  \
# 0        1               79            627      -653.47       -78.96
# 1        2               44            510      -318.96        -9.00
#
#    coupon_match_disc  value_per_user  av_order_value  \
# 0             -24.75         3959.91       50.125443
# 1               0.00         1823.45       41.442045
#
#    av_unique_items_per_order
# 0                   7.936709
# 1                  11.590909

# %%
#вычисляем время суток (ночь/утро/день/вечер) 
data['timeperiod_order'] = 'night'
data.loc[(data.trans_time / 60 > 6) & (data.trans_time / 60 <= 11), 'timeperiod_order'] = 'morning'
data.loc[(data.trans_time / 60 > 17) & (data.trans_time / 60 <= 23), 'timeperiod_order'] = 'evening'
data.loc[(data.trans_time / 60 > 11) & (data.trans_time / 60 <= 17), 'timeperiod_order'] = 'day'

# %%
data.head(2)
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     2375  26984851472    1  1004906         1         1.39       364
# 1     2375  26984851472    1  1033142         1         0.82       364
#
#    retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc  \
# 0         -0.6        1631        1          0.0                0.0
# 1          0.0        1631        1          0.0                0.0
#
#    user_id_orders timeperiod_order
# 0               5            night
# 1               5            night

# %%
#Вычисляем кол-во заказов пользователя по времени суток
users_time_df = data.groupby(['user_id', 'timeperiod_order']).agg({
    'basket_id': 'nunique'}).rename(columns={'basket_id': 'orders_per_timeperiod'})
users_time_df = users_time_df.unstack()
users_time_df.fillna(0, inplace=True)
users_time_df.columns = ['timeperiod_day', 
                          'timeperiod_evening', 
                          'timeperiod_morning', 
                          'timeperiod_night']
users_time_df.reset_index(inplace=True)
users_time_df.head(2)
# Out:
#    user_id  timeperiod_day  timeperiod_evening  timeperiod_morning  \
# 0        1             2.0                35.0                 0.0
# 1        2             0.0                 4.0                 0.0
#
#    timeperiod_night
# 0              42.0
# 1              40.0

# %%
#Вычисляем кол-во заказов пользователя в неделю
users_week_df = data.groupby(['user_id', 'week_no'], as_index=False).agg({
    'basket_id': 'nunique'})
users_week_df = users_week_df.groupby('user_id', as_index=False).agg({
    'basket_id': 'mean'}).rename(columns={'basket_id': 'orders_per_week'})
users_week_df.head(2)
# Out:
#    user_id  orders_per_week
# 0        1         1.234375
# 1        2         1.294118

# %%
#Вычисляем кол-во заказов пользователя в день
users_day_df = data.groupby(['user_id', 'day'], as_index=False).agg({
    'basket_id': 'nunique'})
users_day_df = users_day_df.groupby('user_id', as_index=False).agg({
    'basket_id': 'mean'}).rename(columns={'basket_id': 'orders_per_day'})
users_day_df.head(2)
# Out:
#    user_id  orders_per_day
# 0        1        1.082192
# 1        2        1.000000

# %%
#Вычисляем id магазина, где пользователь чаще всего покупает
users_store_df = data.groupby(['user_id', 'store_id'], as_index=False).agg({
    'basket_id': 'nunique'})
users_store_df = users_store_df.groupby('user_id', as_index=False).agg({
    'basket_id': 'max'}).rename(columns={'basket_id': 'favorite_store_id'})
users_store_df.head(2)
# Out:
#    user_id  favorite_store_id
# 0        1                 78
# 1        2                 25

# %%
#Кол-во товаров на пользователя
users_items_df = data.groupby(['user_id'], as_index=False).agg({
    'item_id': 'sum'}).rename(columns={'item_id': 'items_per_user'})
users_items_df.head(2)
# Out:
#    user_id  items_per_user
# 0        1      4731186649
# 1        2      1910021893

# %%
# Соединяем вместе все датафреймы с вычислениями
users_orders_df_feat = users_orders_df.merge(users_store_df, on='user_id', how='left')
users_orders_df_feat = users_orders_df_feat.merge(users_time_df, on='user_id', how='left')
users_orders_df_feat = users_orders_df_feat.merge(users_week_df, on='user_id', how='left')
users_orders_df_feat = users_orders_df_feat.merge(users_day_df, on='user_id', how='left')
users_orders_df_feat = users_orders_df_feat.merge(users_items_df, on='user_id', how='left')
users_orders_df_feat.head(2)
# Out:
#    user_id  orders_per_user  uniques_items  retail_disc  coupon_disc  \
# 0        1               79            627      -653.47       -78.96
# 1        2               44            510      -318.96        -9.00
#
#    coupon_match_disc  value_per_user  av_order_value  \
# 0             -24.75         3959.91       50.125443
# 1               0.00         1823.45       41.442045
#
#    av_unique_items_per_order  favorite_store_id  timeperiod_day  \
# 0                   7.936709                 78             2.0
# 1                  11.590909                 25             0.0
#
#    timeperiod_evening  timeperiod_morning  timeperiod_night  orders_per_week  \
# 0                35.0                 0.0              42.0         1.234375
# 1                 4.0                 0.0              40.0         1.294118
#
#    orders_per_day  items_per_user
# 0        1.082192      4731186649
# 1        1.000000      1910021893

# %%
users_orders_df_feat['av_items_per_order'] = users_orders_df_feat.items_per_user / users_orders_df_feat.orders_per_user
users_orders_df_feat.head(2)
# Out:
#    user_id  orders_per_user  uniques_items  retail_disc  coupon_disc  \
# 0        1               79            627      -653.47       -78.96
# 1        2               44            510      -318.96        -9.00
#
#    coupon_match_disc  value_per_user  av_order_value  \
# 0             -24.75         3959.91       50.125443
# 1               0.00         1823.45       41.442045
#
#    av_unique_items_per_order  favorite_store_id  timeperiod_day  \
# 0                   7.936709                 78             2.0
# 1                  11.590909                 25             0.0
#
#    timeperiod_evening  timeperiod_morning  timeperiod_night  orders_per_week  \
# 0                35.0                 0.0              42.0         1.234375
# 1                 4.0                 0.0              40.0         1.294118
#
#    orders_per_day  items_per_user  av_items_per_order
# 0        1.082192      4731186649        5.988844e+07
# 1        1.000000      1910021893        4.340959e+07

# %%
user_features.head(2)
# Out:
#   age_desc marital_status_code income_desc homeowner_desc      hh_comp_desc  \
# 0      65+                   A      35-49K      Homeowner  2 Adults No Kids
# 1    45-54                   A      50-74K      Homeowner  2 Adults No Kids
#
#    household_size_desc  kid_category_desc  user_id  income_desc_mean  \
# 0                    2                  0        1                42
# 1                    2                  0        7                63
#
#    age_desc_mean
# 0             70
# 1             50

# %%
# средний income пользователя
user_features['income_desc_mean'] = user_features.income_desc.map({
    'Under 15K': 7,
    '50-74K': 63,
    '35-49K': 42,
    '75-99K': 83,
    '25-34K': 30,
    '15-24K': 20,
    '125-149K': 133,
    '100-124K': 113,
    '150-174K': 163,
    '250K+': 250,
    '175-199K': 188,
    '200-249K': 225,
})

# %%
# средний возраст пользователя
user_features['age_desc_mean'] = user_features.age_desc.map({
    '19-24': 22,
    '25-34': 30,
    '35-44': 40,
    '45-54': 50,
    '55-64': 60,
    '65+': 70,
})

# %%
# средний размер семьи
user_features['household_size_desc'] = user_features.household_size_desc.map({'5+': 5, 
                                                            '1': 1, 
                                                            '2': 2, 
                                                            '3': 3, 
                                                            '4': 4,
                                                           })

# %%
# кол-во детей в семье
user_features['kid_category_desc'] = user_features.kid_category_desc.map({'None/Unknown': 0, 
                                                            '1': 1, 
                                                            '2': 2, 
                                                            '3+': 3, 
                                                           })

# %%
new_user_features_about_users = user_features.drop(['age_desc', 'income_desc', 'hh_comp_desc'], axis=1)
new_user_features_about_users.head(2)
# Out:
#   marital_status_code homeowner_desc  household_size_desc  kid_category_desc  \
# 0                   A      Homeowner                  NaN                NaN
# 1                   A      Homeowner                  NaN                NaN
#
#    user_id  income_desc_mean  age_desc_mean
# 0        1                42             70
# 1        7                63             50

# %%
#добавляем характеристики пользователя
users_orders_df_feat = users_orders_df_feat.merge(new_user_features_about_users, on='user_id', how='left')
users_orders_df_feat.head(2)
# Out:
#    user_id  orders_per_user  uniques_items  retail_disc  coupon_disc  \
# 0        1               79            627      -653.47       -78.96
# 1        2               44            510      -318.96        -9.00
#
#    coupon_match_disc  value_per_user  av_order_value  \
# 0             -24.75         3959.91       50.125443
# 1               0.00         1823.45       41.442045
#
#    av_unique_items_per_order  favorite_store_id  timeperiod_day  \
# 0                   7.936709                 78             2.0
# 1                  11.590909                 25             0.0
#
#    timeperiod_evening  timeperiod_morning  timeperiod_night  orders_per_week  \
# 0                35.0                 0.0              42.0         1.234375
# 1                 4.0                 0.0              40.0         1.294118
#
#    orders_per_day  items_per_user  av_items_per_order marital_status_code  \
# 0        1.082192      4731186649        5.988844e+07                   A
# 1        1.000000      1910021893        4.340959e+07                 NaN
#
#   homeowner_desc  household_size_desc  kid_category_desc  income_desc_mean  \
# 0      Homeowner                  NaN                NaN              42.0
# 1            NaN                  NaN                NaN               NaN
#
#    age_desc_mean
# 0           70.0
# 1            NaN

# %% [markdown]
# #### Фичи для товаров

# %%
item_features.head(2)
# Out:
#    item_id  manufacturer    department  brand            commodity_desc  \
# 0    25671             2       GROCERY      0                  FRZN ICE
# 1    26081             2  MISC. TRANS.      0  NO COMMODITY DESCRIPTION
#
#             sub_commodity_desc curr_size_of_product  items_per_department  \
# 0          ICE - CRUSHED/CUBED                22 LB                 39021
# 1  NO SUBCOMMODITY DESCRIPTION                                        490
#
#    items_per_commodity_desc  items_per_sub_commodity_desc
# 0                        29                            29
# 1                       490                           429

# %%
# СТМ или нет (0, 1) вместо строкового значения
item_features['brand'] = item_features['brand'].map({'National': 0, 'Private': 1})

# %%
#Кол-во товаров по категориальным фичам
item_features['items_per_department'] = item_features['department'].map(item_features.groupby(
    'department').size())

item_features['items_per_commodity_desc'] = item_features['commodity_desc'].map(item_features.groupby(
    'commodity_desc').size())

item_features['items_per_sub_commodity_desc'] = item_features['sub_commodity_desc'].map(item_features.groupby(
    'sub_commodity_desc').size())

# %%
item_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92353 entries, 0 to 92352
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   item_id                       92353 non-null  int64
#  1   manufacturer                  92353 non-null  int64
#  2   department                    92353 non-null  object
#  3   brand                         0 non-null      float64
#  4   commodity_desc                92353 non-null  object
#  5   sub_commodity_desc            92353 non-null  object
#  6   curr_size_of_product          92353 non-null  object
#  7   items_per_department          92353 non-null  int64
#  8   items_per_commodity_desc      92353 non-null  int64
#  9   items_per_sub_commodity_desc  92353 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 7.0+ MB

# %%
item_features.head(2)
# Out:
#    item_id  manufacturer    department  brand            commodity_desc  \
# 0    25671             2       GROCERY    NaN                  FRZN ICE
# 1    26081             2  MISC. TRANS.    NaN  NO COMMODITY DESCRIPTION
#
#             sub_commodity_desc curr_size_of_product  items_per_department  \
# 0          ICE - CRUSHED/CUBED                22 LB                 39021
# 1  NO SUBCOMMODITY DESCRIPTION                                        490
#
#    items_per_commodity_desc  items_per_sub_commodity_desc
# 0                        29                            29
# 1                       490                           429

# %%
# убираем лишнюю фичу
new_item_features = item_features.drop('curr_size_of_product', axis=1)
new_item_features.head(2)
# Out:
#    item_id  manufacturer    department  brand            commodity_desc  \
# 0    25671             2       GROCERY    NaN                  FRZN ICE
# 1    26081             2  MISC. TRANS.    NaN  NO COMMODITY DESCRIPTION
#
#             sub_commodity_desc  items_per_department  \
# 0          ICE - CRUSHED/CUBED                 39021
# 1  NO SUBCOMMODITY DESCRIPTION                   490
#
#    items_per_commodity_desc  items_per_sub_commodity_desc
# 0                        29                            29
# 1                       490                           429

# %%
data.head(2)
# Out:
#    user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 0     2375  26984851472    1  1004906         1         1.39       364
# 1     2375  26984851472    1  1033142         1         0.82       364
#
#    retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc  \
# 0         -0.6        1631        1          0.0                0.0
# 1          0.0        1631        1          0.0                0.0
#
#    user_id_orders timeperiod_order
# 0               5            night
# 1               5            night

# %%
"""
sales_value = quantity * price, та цена, которую платит юзер (скидка уже вычтена) 
retail_disc - аналогично, скидка на весь объем покупки
"""

#Вычисляем кол-во заказов с товаром, кол-во покупок товара, сумму заказов по товару и т.д.
items_orders_df = data.groupby('item_id', as_index=False).agg({
    'basket_id': 'nunique',
    'quantity': 'sum',
    'retail_disc': 'sum',
    'coupon_disc': 'sum',
    'coupon_match_disc': 'sum',
    'sales_value': 'sum'}).rename(columns={'basket_id': 'unique_orders_per_item', 
                                           'quantity': 'amount_items', 
                                           'sales_value': 'value_per_item'})
items_orders_df.head(2)
# Out:
#    item_id  unique_orders_per_item  amount_items  retail_disc  coupon_disc  \
# 0    25671                       3             6          0.0          0.0
# 1    26081                       1             1          0.0          0.0
#
#    coupon_match_disc  value_per_item
# 0                0.0           20.94
# 1                0.0            0.99

# %%
#средняя стоимость товара
items_orders_df['av_item_price'] = items_orders_df.value_per_item / items_orders_df.amount_items

#средняя скидка на товар
items_orders_df['av_item_discount'] = items_orders_df.coupon_disc / items_orders_df.amount_items

# %%
#Кол-во уникальных товаров в датасетах
items_orders_df.shape[0], new_item_features.item_id.nunique()
# Out:
# (89051, 92353)

# %%
items_orders_df_feat = items_orders_df.merge(new_item_features, on='item_id', how='left')
items_orders_df_feat.head(2)
# Out:
#    item_id  unique_orders_per_item  amount_items  retail_disc  coupon_disc  \
# 0    25671                       3             6          0.0          0.0
# 1    26081                       1             1          0.0          0.0
#
#    coupon_match_disc  value_per_item  av_item_price  av_item_discount  \
# 0                0.0           20.94           3.49               0.0
# 1                0.0            0.99           0.99               0.0
#
#    manufacturer    department  brand            commodity_desc  \
# 0             2       GROCERY    NaN                  FRZN ICE
# 1             2  MISC. TRANS.    NaN  NO COMMODITY DESCRIPTION
#
#             sub_commodity_desc  items_per_department  \
# 0          ICE - CRUSHED/CUBED                 39021
# 1  NO SUBCOMMODITY DESCRIPTION                   490
#
#    items_per_commodity_desc  items_per_sub_commodity_desc
# 0                        29                            29
# 1                       490                           429

# %% [markdown]
# #### Объединяем фичи

# %%
targets_lvl_2 = data_train_lvl_2[['user_id', 'item_id']].copy()
targets_lvl_2['target'] = 1  # тут только покупки 

targets_lvl_2 = users_lvl_2.merge(targets_lvl_2, on=['user_id', 'item_id'], how='left')

# Если товара не было в датасете targets_lvl_2, то значит его пользователь не покупал - ставим таргет 0
targets_lvl_2['target'].fillna(0, inplace= True)
targets_lvl_2.drop('drop', axis=1, inplace=True)
targets_lvl_2.head(2)
# Out:
#    user_id  item_id  target
# 0     2070  1029743     0.0
# 1     2070   916122     1.0

# %%
users_orders_df_feat = users_orders_df_feat.rename(columns={'retail_disc': 'retail_disc_user', 
                                                            'coupon_disc': 'coupon_disc_user', 
                                                            'coupon_match_disc': 'coupon_match_disc_user'})
items_orders_df_feat = items_orders_df_feat.rename(columns={'retail_disc': 'retail_disc_item', 
                                                            'coupon_disc': 'coupon_disc_item', 
                                                            'coupon_match_disc': 'coupon_match_disc_item'})

# %%
# Добавляем фичи к датасету, который будем отправлять в модель 2-го уровня
targets_lvl_2 = targets_lvl_2.merge(users_orders_df_feat, on='user_id', how='left')
targets_lvl_2 = targets_lvl_2.merge(items_orders_df_feat, on='item_id', how='left')
targets_lvl_2.head(2)
# Out:
#    user_id  item_id  target  orders_per_user  uniques_items  retail_disc_user  \
# 0     2070  1029743     0.0              540           1289          -1615.06
# 1     2070   916122     1.0              540           1289          -1615.06
#
#    coupon_disc_user  coupon_match_disc_user  value_per_user  av_order_value  \
# 0            -49.15                   -8.45         6981.86        12.92937
# 1            -49.15                   -8.45         6981.86        12.92937
#
#    av_unique_items_per_order  favorite_store_id  timeperiod_day  \
# 0                   2.387037                514            19.0
# 1                   2.387037                514            19.0
#
#    timeperiod_evening  timeperiod_morning  timeperiod_night  orders_per_week  \
# 0                23.0                83.0             415.0         6.585366
# 1                23.0                83.0             415.0         6.585366
#
#    orders_per_day  items_per_user  av_items_per_order marital_status_code  \
# 0         1.69279      7278567672        1.347883e+07                   U
# 1         1.69279      7278567672        1.347883e+07                   U
#
#   homeowner_desc  household_size_desc  kid_category_desc  income_desc_mean  \
# 0        Unknown                  NaN                NaN              63.0
# 1        Unknown                  NaN                NaN              63.0
#
#    age_desc_mean  unique_orders_per_item  amount_items  retail_disc_item  \
# 0           50.0                 13455.0       15840.0          -2582.01
# 1           50.0                  4082.0        6493.0         -27890.91
#
#    coupon_disc_item  coupon_match_disc_item  value_per_item  av_item_price  \
# 0            -62.02                     0.0        37981.91       2.397848
# 1              0.00                     0.0        26828.79       4.131956
#
#    av_item_discount  manufacturer department  brand       commodity_desc  \
# 0         -0.003915          69.0    GROCERY    NaN  FLUID MILK PRODUCTS
# 1          0.000000        4314.0       MEAT    NaN              CHICKEN
#
#         sub_commodity_desc  items_per_department  items_per_commodity_desc  \
# 0    FLUID MILK WHITE ONLY               39021.0                     455.0
# 1  CHICKEN BREAST BONELESS                2544.0                     364.0
#
#    items_per_sub_commodity_desc
# 0                         194.0
# 1                          57.0

# %%
#где и сколько пропусков
targets_lvl_2.isna().sum()
# Out:
# user_id                              0
# item_id                              0
# target                               0
# orders_per_user                      0
# uniques_items                        0
# retail_disc_user                     0
# coupon_disc_user                     0
# coupon_match_disc_user               0
# value_per_user                       0
# av_order_value                       0
# av_unique_items_per_order            0
# favorite_store_id                    0
# timeperiod_day                       0
# timeperiod_evening                   0
# timeperiod_morning                   0
# timeperiod_night                     0
# orders_per_week                      0
# orders_per_day                       0
# items_per_user                       0
# av_items_per_order                   0
# marital_status_code             274930
# homeowner_desc                  274930
# household_size_desc             438129
# kid_category_desc               438129
# income_desc_mean                274930
# age_desc_mean                   274930
# unique_orders_per_item            2043
# amount_items                      2043
# retail_disc_item                  2043
# coupon_disc_item                  2043
# coupon_match_disc_item            2043
# value_per_item                    2043
# av_item_price                     2043
# av_item_discount                  2043
# manufacturer                      2043
# department                        2043
# brand                           438129
# commodity_desc                    2043
# sub_commodity_desc                2043
# items_per_department              2043
# items_per_commodity_desc          2043
# items_per_sub_commodity_desc      2043
# dtype: int64

# %%
# Сколько значений в целевых классах:
targets_lvl_2['target'].value_counts()
# Out:
# 0.0    410787
# 1.0     27342
# Name: target, dtype: int64

# %%
targets_lvl_2['target'].mean()
# Out:
# 0.06240627760317167

# %%
targets_lvl_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 438129 entries, 0 to 438128
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   user_id                       438129 non-null  int64
#  1   item_id                       438129 non-null  int64
#  2   target                        438129 non-null  float64
#  3   orders_per_user               438129 non-null  int64
#  4   uniques_items                 438129 non-null  int64
#  5   retail_disc_user              438129 non-null  float64
#  6   coupon_disc_user              438129 non-null  float64
#  7   coupon_match_disc_user        438129 non-null  float64
#  8   value_per_user                438129 non-null  float64
#  9   av_order_value                438129 non-null  float64
#  10  av_unique_items_per_order     438129 non-null  float64
#  11  favorite_store_id             438129 non-null  int64
#  12  timeperiod_day                438129 non-null  float64
#  13  timeperiod_evening            438129 non-null  float64
#  14  timeperiod_morning            438129 non-null  float64
#  15  timeperiod_night              438129 non-null  float64
#  16  orders_per_week               438129 non-null  float64
#  17  orders_per_day                438129 non-null  float64
#  18  items_per_user                438129 non-null  int64
#  19  av_items_per_order            438129 non-null  float64
#  20  marital_status_code           163199 non-null  object
#  21  homeowner_desc                163199 non-null  object
#  22  household_size_desc           0 non-null       float64
#  23  kid_category_desc             0 non-null       float64
#  24  income_desc_mean              163199 non-null  float64
#  25  age_desc_mean                 163199 non-null  float64
#  26  unique_orders_per_item        436086 non-null  float64
#  27  amount_items                  436086 non-null  float64
#  28  retail_disc_item              436086 non-null  float64
#  29  coupon_disc_item              436086 non-null  float64
#  30  coupon_match_disc_item        436086 non-null  float64
#  31  value_per_item                436086 non-null  float64
#  32  av_item_price                 436086 non-null  float64
#  33  av_item_discount              436086 non-null  float64
#  34  manufacturer                  436086 non-null  float64
#  35  department                    436086 non-null  object
#  36  brand                         0 non-null       float64
#  37  commodity_desc                436086 non-null  object
#  38  sub_commodity_desc            436086 non-null  object
#  39  items_per_department          436086 non-null  float64
#  40  items_per_commodity_desc      436086 non-null  float64
#  41  items_per_sub_commodity_desc  436086 non-null  float64
# dtypes: float64(31), int64(6), object(5)
# memory usage: 143.7+ MB

# %% [markdown]
# ### Поменяем фичи в валидационном датасете

# %%
# создаем датасет с униками из data_val_lvl_2
users_val_lvl_2 = pd.DataFrame(data_val_lvl_2['user_id'].unique())
users_val_lvl_2.columns = ['user_id']
users_val_lvl_2['user_id'].nunique()
# Out:
# 2042

# %%
# получаем собственные покупки пользователей датасета data_val_lvl_2 через предсказания ItemItemRecommender
users_val_lvl_2['candidates'] = users_val_lvl_2['user_id'].apply(lambda x: recommender.get_own_recommendations(x, N=200))
users_val_lvl_2.head(2)
# Out:
#    user_id                                         candidates
# 0      338  [1029743, 844179, 1106523, 1127831, 1004906, 8...
# 1     2120  [999999, 1029743, 1106523, 5569230, 916122, 84...

# %%
# переводим колонку с собственными покупками в строки, чтобы было соответствие user_id - item_id
s = users_val_lvl_2.apply(lambda x: pd.Series(x['candidates']), axis=1).stack().reset_index(level=1, drop=True)
s.name = 'item_id'

users_val_lvl_2 = users_val_lvl_2.drop('candidates', axis=1).join(s)
users_val_lvl_2['drop'] = 1  # фиктивная переменная

users_val_lvl_2.head(4)
# Out:
#    user_id  item_id  drop
# 0      338  1029743     1
# 0      338   844179     1
# 0      338  1106523     1
# 0      338  1127831     1

# %%
#Всего строк в таблице собственных покупок и всего уников
users_val_lvl_2.shape[0], users_val_lvl_2['user_id'].nunique()
# Out:
# (408400, 2042)

# %%
data_val_lvl_2.head(2)
# Out:
#          user_id    basket_id  day  item_id  quantity  sales_value  store_id  \
# 2277416      338  41260573635  636   840173         1         1.99       369
# 2277417      338  41260573635  636  1037348         1         0.89       369
#
#          retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 2277416          0.0         112       92          0.0                0.0
# 2277417         -0.3         112       92          0.0                0.0

# %%
targets_val_lvl_2 = data_val_lvl_2[['user_id', 'item_id']].copy()
targets_val_lvl_2['target'] = 1  # тут только покупки 

targets_val_lvl_2 = users_val_lvl_2.merge(targets_val_lvl_2, on=['user_id', 'item_id'], how='left')

# Если товара не было в датасете targets_lvl_2, то значит его пользователь не покупал - ставим таргет 0
targets_val_lvl_2['target'].fillna(0, inplace= True)
targets_val_lvl_2.drop('drop', axis=1, inplace=True)
targets_val_lvl_2.head(2)
# Out:
#    user_id  item_id  target
# 0      338  1029743     0.0
# 1      338   844179     0.0

# %%
# Добавляем фичи к датасету, который будем отправлять в модель 2-го уровня
targets_val_lvl_2 = targets_val_lvl_2.merge(users_orders_df_feat, on='user_id', how='left')
targets_val_lvl_2 = targets_val_lvl_2.merge(items_orders_df_feat, on='item_id', how='left')
targets_val_lvl_2.head(2)
# Out:
#    user_id  item_id  target  orders_per_user  uniques_items  retail_disc_user  \
# 0      338  1029743     0.0              128            473           -466.13
# 1      338   844179     0.0              128            473           -466.13
#
#    coupon_disc_user  coupon_match_disc_user  value_per_user  av_order_value  \
# 0               0.0                     0.0         2252.54       17.597969
# 1               0.0                     0.0         2252.54       17.597969
#
#    av_unique_items_per_order  favorite_store_id  timeperiod_day  \
# 0                   3.695312                 38             2.0
# 1                   3.695312                 38             2.0
#
#    timeperiod_evening  timeperiod_morning  timeperiod_night  orders_per_week  \
# 0                20.0                 0.0             106.0         2.245614
# 1                20.0                 0.0             106.0         2.245614
#
#    orders_per_day  items_per_user  av_items_per_order marital_status_code  \
# 0        1.174312      2133458983        1.666765e+07                 NaN
# 1        1.174312      2133458983        1.666765e+07                 NaN
#
#   homeowner_desc  household_size_desc  kid_category_desc  income_desc_mean  \
# 0            NaN                  NaN                NaN               NaN
# 1            NaN                  NaN                NaN               NaN
#
#    age_desc_mean  unique_orders_per_item  amount_items  retail_disc_item  \
# 0            NaN                 13455.0       15840.0          -2582.01
# 1            NaN                  3537.0        4877.0          -4876.98
#
#    coupon_disc_item  coupon_match_disc_item  value_per_item  av_item_price  \
# 0            -62.02                     0.0        37981.91       2.397848
# 1              0.00                     0.0        18094.23       3.710115
#
#    av_item_discount  manufacturer department  brand       commodity_desc  \
# 0         -0.003915          69.0    GROCERY    NaN  FLUID MILK PRODUCTS
# 1          0.000000        2852.0       MEAT    NaN                 BEEF
#
#       sub_commodity_desc  items_per_department  items_per_commodity_desc  \
# 0  FLUID MILK WHITE ONLY               39021.0                     455.0
# 1                 PRIMAL                2544.0                    1109.0
#
#    items_per_sub_commodity_desc
# 0                         194.0
# 1                         111.0

# %%
#где и сколько пропусков
targets_val_lvl_2.isna().sum()
# Out:
# user_id                              0
# item_id                              0
# target                               0
# orders_per_user                      0
# uniques_items                        0
# retail_disc_user                     0
# coupon_disc_user                     0
# coupon_match_disc_user               0
# value_per_user                       0
# av_order_value                       0
# av_unique_items_per_order            0
# favorite_store_id                    0
# timeperiod_day                       0
# timeperiod_evening                   0
# timeperiod_morning                   0
# timeperiod_night                     0
# orders_per_week                      0
# orders_per_day                       0
# items_per_user                       0
# av_items_per_order                   0
# marital_status_code             257170
# homeowner_desc                  257170
# household_size_desc             412473
# kid_category_desc               412473
# income_desc_mean                257170
# age_desc_mean                   257170
# unique_orders_per_item            1935
# amount_items                      1935
# retail_disc_item                  1935
# coupon_disc_item                  1935
# coupon_match_disc_item            1935
# value_per_item                    1935
# av_item_price                     1935
# av_item_discount                  1935
# manufacturer                      1935
# department                        1935
# brand                           412473
# commodity_desc                    1935
# sub_commodity_desc                1935
# items_per_department              1935
# items_per_commodity_desc          1935
# items_per_sub_commodity_desc      1935
# dtype: int64

# %%
# Сколько значений в целевых классах:
targets_val_lvl_2['target'].value_counts()
# Out:
# 0.0    393486
# 1.0     18987
# Name: target, dtype: int64

# %% [markdown]
# ### Запускаем модель

# %%
X_train = targets_lvl_2.drop('target', axis=1)
y_train = targets_lvl_2[['target']]

X_valid = targets_val_lvl_2.drop('target', axis=1)
y_valid = targets_val_lvl_2[['target']]

# %%
X_train.shape, X_valid.shape
# Out:
# ((438129, 41), (412473, 41))

# %%
cat_feats = [
    'department',
    'commodity_desc',
    'sub_commodity_desc',
    'marital_status_code',
    'homeowner_desc',
]

# %%
X_train[cat_feats] = X_train[cat_feats].astype('category')
X_valid[cat_feats] = X_valid[cat_feats].astype('category')

# %%
# %%time

lgb = LGBMClassifier(objective='binary', max_depth=7, categorical_column=cat_feats)
lgb.fit(X_train, y_train)

train_preds = lgb.predict(X_train)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Anaconda\lib\site-packages\lightgbm\basic.py:863: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# Wall time: 5.82 s

# %%
valid_preds = lgb.predict(X_valid)

# %%
from sklearn.metrics import confusion_matrix, f1_score

# %%
confusion_matrix(y_train, train_preds)
# Out:
# array([[409263,   1524],
#        [ 23556,   3786]], dtype=int64)

# %%
confusion_matrix(y_valid, valid_preds)
# Out:
# array([[391665,   1821],
#        [ 16784,   2203]], dtype=int64)

# %%
f1_score(y_valid, valid_preds)
# Out:
# 0.19147364304028505

# %%
f1_score(y_train, train_preds)
# Out:
# 0.23190003675119442

# %%
valid_preds_proba = lgb.predict_proba(X_valid)

# %%
result = pd.concat([X_valid, pd.DataFrame(valid_preds_proba)], axis=1)
result.shape
# Out:
# (412473, 43)

# %%
result.sort_values(by=[1], ascending=False, inplace=True)
result.head(2)
# Out:
#        user_id  item_id  orders_per_user  uniques_items  retail_disc_user  \
# 22750     1609  1082185              383           1537          -2256.98
# 22744     1609  1082185              383           1537          -2256.98
#
#        coupon_disc_user  coupon_match_disc_user  value_per_user  \
# 22750            -77.48                   -22.5        26081.05
# 22744            -77.48                   -22.5        26081.05
#
#        av_order_value  av_unique_items_per_order  favorite_store_id  \
# 22750       68.096736                   4.013055                196
# 22744       68.096736                   4.013055                196
#
#        timeperiod_day  timeperiod_evening  timeperiod_morning  \
# 22750            35.0               206.0                 1.0
# 22744            35.0               206.0                 1.0
#
#        timeperiod_night  orders_per_week  orders_per_day  items_per_user  \
# 22750             141.0         4.352273        1.268212     17744636782
# 22744             141.0         4.352273        1.268212     17744636782
#
#        av_items_per_order marital_status_code homeowner_desc  \
# 22750        4.633064e+07                   A      Homeowner
# 22744        4.633064e+07                   A      Homeowner
#
#        household_size_desc  kid_category_desc  income_desc_mean  \
# 22750                  NaN                NaN             133.0
# 22744                  NaN                NaN             133.0
#
#        age_desc_mean  unique_orders_per_item  amount_items  retail_disc_item  \
# 22750           50.0                 27362.0       28384.0          -1924.23
# 22744           50.0                 27362.0       28384.0          -1924.23
#
#        coupon_disc_item  coupon_match_disc_item  value_per_item  \
# 22750               0.0                     0.0        27291.02
# 22744               0.0                     0.0        27291.02
#
#        av_item_price  av_item_discount  manufacturer department  brand  \
# 22750       0.961493               0.0           2.0    PRODUCE    NaN
# 22744       0.961493               0.0           2.0    PRODUCE    NaN
#
#        commodity_desc sub_commodity_desc  items_per_department  \
# 22750  TROPICAL FRUIT            BANANAS                3118.0
# 22744  TROPICAL FRUIT            BANANAS                3118.0
#
#        items_per_commodity_desc  items_per_sub_commodity_desc         0  \
# 22750                      83.0                          17.0  0.043719
# 22744                      83.0                          17.0  0.043719
#
#               1
# 22750  0.956281
# 22744  0.956281

# %%
X_train.sort_values(by=['item_id'], ascending=False).head(30)
# Out:
#         user_id   item_id  orders_per_user  uniques_items  retail_disc_user  \
# 203725     1752  15926886              186           1133          -1384.15
# 380513     2482  15926886               68            667           -565.64
# 228603     1284  15926886              141            416           -357.71
# 228604     1284  15926886              141            416           -357.71
# 228605     1284  15926886              141            416           -357.71
# 228606     1284  15926886              141            416           -357.71
# 228607     1284  15926886              141            416           -357.71
# 28575      1762  15926886              309           1905          -2423.56
# 228608     1284  15926886              141            416           -357.71
# 83459      1293  15926886              157            646           -327.69
# 90256       878  15926886              171           1047          -1379.71
# 90255       878  15926886              171           1047          -1379.71
# 95312      2115  15926886              301           1482          -1382.80
# 230985     1845  15926886              141           1550          -1428.61
# 203547     1024  15926886              135           1082          -1923.81
# 219030      805  15926886              266            609          -1178.38
# 145485     2371  15926886               96            372           -214.79
# 176980     1020  15926886              157           1429          -1294.99
# 176981     1020  15926886              157           1429          -1294.99
# 195746      131  15926886              346           1282          -1180.29
# 410171     1003  15926886               62            552           -590.99
# 237876     2240  15926886              204            813           -928.49
# 5388       1740  15926886              342            856          -1238.62
# 221722      283  15926886               70            983           -790.44
# 10998      1947  15926886               78            604           -873.15
# 5837        883  15926886              320           1042          -1130.53
# 384750       49  15926886              110            981          -1286.09
# 58210       536  15926886               83            476           -426.82
# 292134     1988  15926886              174           1019          -1186.78
# 228602     1284  15926886              141            416           -357.71
#
#         coupon_disc_user  coupon_match_disc_user  value_per_user  \
# 203725             -6.70                   -2.70         6150.26
# 380513             -6.29                    0.00         2495.53
# 228603             -6.39                    0.00         1693.01
# 228604             -6.39                    0.00         1693.01
# 228605             -6.39                    0.00         1693.01
# 228606             -6.39                    0.00         1693.01
# 228607             -6.39                    0.00         1693.01
# 28575             -53.07                   -3.50        13826.69
# 228608             -6.39                    0.00         1693.01
# 83459               0.00                    0.00         2510.24
# 90256              -1.00                    0.00         5517.45
# 90255              -1.00                    0.00         5517.45
# 95312            -160.01                  -51.38        13572.51
# 230985            -15.29                   -2.20        11920.59
# 203547            -55.68                   -9.30         8637.97
# 219030            -21.00                   -1.50         4692.47
# 145485              0.00                    0.00         2116.27
# 176980            -13.18                   -0.50         8497.29
# 176981            -13.18                   -0.50         8497.29
# 195746            -69.67                   -2.30         5935.49
# 410171             -3.50                    0.00         2542.17
# 237876            -32.69                   -0.50         5067.47
# 5388               -8.00                    0.00        10790.24
# 221722            -23.27                   -1.15         5187.79
# 10998             -17.15                   -1.85         6552.52
# 5837              -11.00                    0.00         9426.18
# 384750            -13.34                   -0.75         5781.62
# 58210              -6.50                   -1.50         1470.24
# 292134            -74.30                   -5.15         7147.80
# 228602             -6.39                    0.00         1693.01
#
#         av_order_value  av_unique_items_per_order  favorite_store_id  \
# 203725       33.065914                   6.091398                 47
# 380513       36.698971                   9.808824                 54
# 228603       12.007163                   2.950355                103
# 228604       12.007163                   2.950355                103
# 228605       12.007163                   2.950355                103
# 228606       12.007163                   2.950355                103
# 228607       12.007163                   2.950355                103
# 28575        44.746570                   6.165049                147
# 228608       12.007163                   2.950355                103
# 83459        15.988790                   4.114650                140
# 90256        32.265789                   6.122807                 93
# 90255        32.265789                   6.122807                 93
# 95312        45.091395                   4.923588                275
# 230985       84.543191                  10.992908                 99
# 203547       63.984963                   8.014815                 78
# 219030       17.640865                   2.289474                236
# 145485       22.044479                   3.875000                 26
# 176980       54.122866                   9.101911                146
# 176981       54.122866                   9.101911                146
# 195746       17.154595                   3.705202                279
# 410171       41.002742                   8.903226                 59
# 237876       24.840539                   3.985294                197
# 5388         31.550409                   2.502924                170
# 221722       74.111286                  14.042857                 43
# 10998        84.006667                   7.743590                 72
# 5837         29.456812                   3.256250                278
# 384750       52.560182                   8.918182                 70
# 58210        17.713735                   5.734940                 57
# 292134       41.079310                   5.856322                142
# 228602       12.007163                   2.950355                103
#
#         timeperiod_day  timeperiod_evening  timeperiod_morning  \
# 203725            10.0                21.0                 0.0
# 380513             0.0                 9.0                 0.0
# 228603             4.0                32.0                 0.0
# 228604             4.0                32.0                 0.0
# 228605             4.0                32.0                 0.0
# 228606             4.0                32.0                 0.0
# 228607             4.0                32.0                 0.0
# 28575            106.0                61.0                 0.0
# 228608             4.0                32.0                 0.0
# 83459             27.0                76.0                 0.0
# 90256             10.0                43.0                 0.0
# 90255             10.0                43.0                 0.0
# 95312             42.0                85.0                 1.0
# 230985             8.0                34.0                 0.0
# 203547             4.0                31.0                 0.0
# 219030            37.0                69.0                 5.0
# 145485             2.0                17.0                 0.0
# 176980             4.0                34.0                 0.0
# 176981             4.0                34.0                 0.0
# 195746            31.0                71.0                 7.0
# 410171             2.0                 3.0                 0.0
# 237876            11.0                37.0                 0.0
# 5388              20.0               131.0                 1.0
# 221722             9.0                16.0                 0.0
# 10998              1.0                20.0                 0.0
# 5837              17.0                94.0                 8.0
# 384750             5.0                14.0                 0.0
# 58210              0.0                12.0                 2.0
# 292134             3.0                37.0                 0.0
# 228602             4.0                32.0                 0.0
#
#         timeperiod_night  orders_per_week  orders_per_day  items_per_user  \
# 203725             155.0         2.480000        1.338129      5563312127
# 380513              59.0         1.700000        1.333333      2289398280
# 228603             105.0         2.517857        1.184874      2415584432
# 228604             105.0         2.517857        1.184874      2415584432
# 228605             105.0         2.517857        1.184874      2415584432
# 228606             105.0         2.517857        1.184874      2415584432
# 228607             105.0         2.517857        1.184874      2415584432
# 28575              142.0         3.814815        1.236000     11877123974
# 228608             105.0         2.517857        1.184874      2415584432
# 83459               54.0         2.180556        1.113475      2937051765
# 90256              118.0         2.280000        1.239130      5283297679
# 90255              118.0         2.280000        1.239130      5283297679
# 95312              173.0         3.626506        1.308696      9578940324
# 230985              99.0         1.740741        1.052239     12674908779
# 203547             100.0         2.213115        1.205357      5269833344
# 219030             155.0         2.988764        1.303922      3370158972
# 145485              77.0         1.500000        1.066667      1707010867
# 176980             119.0         2.180556        1.121429      9592602165
# 176981             119.0         2.180556        1.121429      9592602165
# 195746             237.0         4.023256        1.472340      5264377635
# 410171              57.0         1.631579        1.347826      2322642733
# 237876             156.0         2.720000        1.500000      4401996139
# 5388               190.0         5.896552        1.443038      8772252709
# 221722              45.0         1.346154        1.060606      5130793579
# 10998               57.0         1.471698        1.054054      5027333189
# 5837               201.0         3.809524        1.333333      5772271150
# 384750              91.0         1.833333        1.122449      4241185765
# 58210               69.0         1.537037        1.152778      1553849583
# 292134             134.0         2.597015        1.438017      4470199548
# 228602             105.0         2.517857        1.184874      2415584432
#
#         av_items_per_order marital_status_code homeowner_desc  \
# 203725        2.991028e+07                 NaN            NaN
# 380513        3.366762e+07                 NaN            NaN
# 228603        1.713180e+07                 NaN            NaN
# 228604        1.713180e+07                 NaN            NaN
# 228605        1.713180e+07                 NaN            NaN
# 228606        1.713180e+07                 NaN            NaN
# 228607        1.713180e+07                 NaN            NaN
# 28575         3.843729e+07                   A      Homeowner
# 228608        1.713180e+07                 NaN            NaN
# 83459         1.870734e+07                 NaN            NaN
# 90256         3.089648e+07                   U        Unknown
# 90255         3.089648e+07                   U        Unknown
# 95312         3.182372e+07                   A      Homeowner
# 230985        8.989297e+07                   U        Unknown
# 203547        3.903580e+07                   A      Homeowner
# 219030        1.266977e+07                 NaN            NaN
# 145485        1.778136e+07                 NaN            NaN
# 176980        6.109938e+07                   A      Homeowner
# 176981        6.109938e+07                   A      Homeowner
# 195746        1.521496e+07                   U        Unknown
# 410171        3.746198e+07                   U        Unknown
# 237876        2.157841e+07                 NaN            NaN
# 5388          2.564986e+07                   U        Unknown
# 221722        7.329705e+07                   A      Homeowner
# 10998         6.445299e+07                 NaN            NaN
# 5837          1.803835e+07                   A      Homeowner
# 384750        3.855623e+07                   A      Homeowner
# 58210         1.872108e+07                 NaN            NaN
# 292134        2.569080e+07                 NaN            NaN
# 228602        1.713180e+07                 NaN            NaN
#
#         household_size_desc  kid_category_desc  income_desc_mean  \
# 203725                  NaN                NaN               NaN
# 380513                  NaN                NaN               NaN
# 228603                  NaN                NaN               NaN
# 228604                  NaN                NaN               NaN
# 228605                  NaN                NaN               NaN
# 228606                  NaN                NaN               NaN
# 228607                  NaN                NaN               NaN
# 28575                   NaN                NaN             133.0
# 228608                  NaN                NaN               NaN
# 83459                   NaN                NaN               NaN
# 90256                   NaN                NaN              42.0
# 90255                   NaN                NaN              42.0
# 95312                   NaN                NaN             163.0
# 230985                  NaN                NaN             188.0
# 203547                  NaN                NaN               7.0
# 219030                  NaN                NaN               NaN
# 145485                  NaN                NaN               NaN
# 176980                  NaN                NaN              30.0
# 176981                  NaN                NaN              30.0
# 195746                  NaN                NaN              63.0
# 410171                  NaN                NaN              30.0
# 237876                  NaN                NaN               NaN
# 5388                    NaN                NaN             250.0
# 221722                  NaN                NaN              63.0
# 10998                   NaN                NaN               NaN
# 5837                    NaN                NaN              42.0
# 384750                  NaN                NaN              42.0
# 58210                   NaN                NaN               NaN
# 292134                  NaN                NaN               NaN
# 228602                  NaN                NaN               NaN
#
#         age_desc_mean  unique_orders_per_item  amount_items  retail_disc_item  \
# 203725            NaN                   356.0         378.0           -106.92
# 380513            NaN                   356.0         378.0           -106.92
# 228603            NaN                   356.0         378.0           -106.92
# 228604            NaN                   356.0         378.0           -106.92
# 228605            NaN                   356.0         378.0           -106.92
# 228606            NaN                   356.0         378.0           -106.92
# 228607            NaN                   356.0         378.0           -106.92
# 28575            50.0                   356.0         378.0           -106.92
# 228608            NaN                   356.0         378.0           -106.92
# 83459             NaN                   356.0         378.0           -106.92
# 90256            30.0                   356.0         378.0           -106.92
# 90255            30.0                   356.0         378.0           -106.92
# 95312            40.0                   356.0         378.0           -106.92
# 230985           50.0                   356.0         378.0           -106.92
# 203547           30.0                   356.0         378.0           -106.92
# 219030            NaN                   356.0         378.0           -106.92
# 145485            NaN                   356.0         378.0           -106.92
# 176980           50.0                   356.0         378.0           -106.92
# 176981           50.0                   356.0         378.0           -106.92
# 195746           50.0                   356.0         378.0           -106.92
# 410171           40.0                   356.0         378.0           -106.92
# 237876            NaN                   356.0         378.0           -106.92
# 5388             22.0                   356.0         378.0           -106.92
# 221722           30.0                   356.0         378.0           -106.92
# 10998             NaN                   356.0         378.0           -106.92
# 5837             40.0                   356.0         378.0           -106.92
# 384750           40.0                   356.0         378.0           -106.92
# 58210             NaN                   356.0         378.0           -106.92
# 292134            NaN                   356.0         378.0           -106.92
# 228602            NaN                   356.0         378.0           -106.92
#
#         coupon_disc_item  coupon_match_disc_item  value_per_item  \
# 203725            -11.19                     0.0          837.08
# 380513            -11.19                     0.0          837.08
# 228603            -11.19                     0.0          837.08
# 228604            -11.19                     0.0          837.08
# 228605            -11.19                     0.0          837.08
# 228606            -11.19                     0.0          837.08
# 228607            -11.19                     0.0          837.08
# 28575             -11.19                     0.0          837.08
# 228608            -11.19                     0.0          837.08
# 83459             -11.19                     0.0          837.08
# 90256             -11.19                     0.0          837.08
# 90255             -11.19                     0.0          837.08
# 95312             -11.19                     0.0          837.08
# 230985            -11.19                     0.0          837.08
# 203547            -11.19                     0.0          837.08
# 219030            -11.19                     0.0          837.08
# 145485            -11.19                     0.0          837.08
# 176980            -11.19                     0.0          837.08
# 176981            -11.19                     0.0          837.08
# 195746            -11.19                     0.0          837.08
# 410171            -11.19                     0.0          837.08
# 237876            -11.19                     0.0          837.08
# 5388              -11.19                     0.0          837.08
# 221722            -11.19                     0.0          837.08
# 10998             -11.19                     0.0          837.08
# 5837              -11.19                     0.0          837.08
# 384750            -11.19                     0.0          837.08
# 58210             -11.19                     0.0          837.08
# 292134            -11.19                     0.0          837.08
# 228602            -11.19                     0.0          837.08
#
#         av_item_price  av_item_discount  manufacturer department  brand  \
# 203725       2.214497         -0.029603         544.0    GROCERY    NaN
# 380513       2.214497         -0.029603         544.0    GROCERY    NaN
# 228603       2.214497         -0.029603         544.0    GROCERY    NaN
# 228604       2.214497         -0.029603         544.0    GROCERY    NaN
# 228605       2.214497         -0.029603         544.0    GROCERY    NaN
# 228606       2.214497         -0.029603         544.0    GROCERY    NaN
# 228607       2.214497         -0.029603         544.0    GROCERY    NaN
# 28575        2.214497         -0.029603         544.0    GROCERY    NaN
# 228608       2.214497         -0.029603         544.0    GROCERY    NaN
# 83459        2.214497         -0.029603         544.0    GROCERY    NaN
# 90256        2.214497         -0.029603         544.0    GROCERY    NaN
# 90255        2.214497         -0.029603         544.0    GROCERY    NaN
# 95312        2.214497         -0.029603         544.0    GROCERY    NaN
# 230985       2.214497         -0.029603         544.0    GROCERY    NaN
# 203547       2.214497         -0.029603         544.0    GROCERY    NaN
# 219030       2.214497         -0.029603         544.0    GROCERY    NaN
# 145485       2.214497         -0.029603         544.0    GROCERY    NaN
# 176980       2.214497         -0.029603         544.0    GROCERY    NaN
# 176981       2.214497         -0.029603         544.0    GROCERY    NaN
# 195746       2.214497         -0.029603         544.0    GROCERY    NaN
# 410171       2.214497         -0.029603         544.0    GROCERY    NaN
# 237876       2.214497         -0.029603         544.0    GROCERY    NaN
# 5388         2.214497         -0.029603         544.0    GROCERY    NaN
# 221722       2.214497         -0.029603         544.0    GROCERY    NaN
# 10998        2.214497         -0.029603         544.0    GROCERY    NaN
# 5837         2.214497         -0.029603         544.0    GROCERY    NaN
# 384750       2.214497         -0.029603         544.0    GROCERY    NaN
# 58210        2.214497         -0.029603         544.0    GROCERY    NaN
# 292134       2.214497         -0.029603         544.0    GROCERY    NaN
# 228602       2.214497         -0.029603         544.0    GROCERY    NaN
#
#        commodity_desc sub_commodity_desc  items_per_department  \
# 203725     BAG SNACKS       POTATO CHIPS               39021.0
# 380513     BAG SNACKS       POTATO CHIPS               39021.0
# 228603     BAG SNACKS       POTATO CHIPS               39021.0
# 228604     BAG SNACKS       POTATO CHIPS               39021.0
# 228605     BAG SNACKS       POTATO CHIPS               39021.0
# 228606     BAG SNACKS       POTATO CHIPS               39021.0
# 228607     BAG SNACKS       POTATO CHIPS               39021.0
# 28575      BAG SNACKS       POTATO CHIPS               39021.0
# 228608     BAG SNACKS       POTATO CHIPS               39021.0
# 83459      BAG SNACKS       POTATO CHIPS               39021.0
# 90256      BAG SNACKS       POTATO CHIPS               39021.0
# 90255      BAG SNACKS       POTATO CHIPS               39021.0
# 95312      BAG SNACKS       POTATO CHIPS               39021.0
# 230985     BAG SNACKS       POTATO CHIPS               39021.0
# 203547     BAG SNACKS       POTATO CHIPS               39021.0
# 219030     BAG SNACKS       POTATO CHIPS               39021.0
# 145485     BAG SNACKS       POTATO CHIPS               39021.0
# 176980     BAG SNACKS       POTATO CHIPS               39021.0
# 176981     BAG SNACKS       POTATO CHIPS               39021.0
# 195746     BAG SNACKS       POTATO CHIPS               39021.0
# 410171     BAG SNACKS       POTATO CHIPS               39021.0
# 237876     BAG SNACKS       POTATO CHIPS               39021.0
# 5388       BAG SNACKS       POTATO CHIPS               39021.0
# 221722     BAG SNACKS       POTATO CHIPS               39021.0
# 10998      BAG SNACKS       POTATO CHIPS               39021.0
# 5837       BAG SNACKS       POTATO CHIPS               39021.0
# 384750     BAG SNACKS       POTATO CHIPS               39021.0
# 58210      BAG SNACKS       POTATO CHIPS               39021.0
# 292134     BAG SNACKS       POTATO CHIPS               39021.0
# 228602     BAG SNACKS       POTATO CHIPS               39021.0
#
#         items_per_commodity_desc  items_per_sub_commodity_desc
# 203725                    1523.0                         531.0
# 380513                    1523.0                         531.0
# 228603                    1523.0                         531.0
# 228604                    1523.0                         531.0
# 228605                    1523.0                         531.0
# 228606                    1523.0                         531.0
# 228607                    1523.0                         531.0
# 28575                     1523.0                         531.0
# 228608                    1523.0                         531.0
# 83459                     1523.0                         531.0
# 90256                     1523.0                         531.0
# 90255                     1523.0                         531.0
# 95312                     1523.0                         531.0
# 230985                    1523.0                         531.0
# 203547                    1523.0                         531.0
# 219030                    1523.0                         531.0
# 145485                    1523.0                         531.0
# 176980                    1523.0                         531.0
# 176981                    1523.0                         531.0
# 195746                    1523.0                         531.0
# 410171                    1523.0                         531.0
# 237876                    1523.0                         531.0
# 5388                      1523.0                         531.0
# 221722                    1523.0                         531.0
# 10998                     1523.0                         531.0
# 5837                      1523.0                         531.0
# 384750                    1523.0                         531.0
# 58210                     1523.0                         531.0
# 292134                    1523.0                         531.0
# 228602                    1523.0                         531.0

# %%
result.head(10)
# Out:
#         user_id  item_id  orders_per_user  uniques_items  retail_disc_user  \
# 22750      1609  1082185              383           1537          -2256.98
# 22744      1609  1082185              383           1537          -2256.98
# 22749      1609  1082185              383           1537          -2256.98
# 22748      1609  1082185              383           1537          -2256.98
# 22747      1609  1082185              383           1537          -2256.98
# 22746      1609  1082185              383           1537          -2256.98
# 22745      1609  1082185              383           1537          -2256.98
# 141995     2317  1082185              142           1789          -2889.98
# 141996     2317  1082185              142           1789          -2889.98
# 141994     2317  1082185              142           1789          -2889.98
#
#         coupon_disc_user  coupon_match_disc_user  value_per_user  \
# 22750             -77.48                   -22.5        26081.05
# 22744             -77.48                   -22.5        26081.05
# 22749             -77.48                   -22.5        26081.05
# 22748             -77.48                   -22.5        26081.05
# 22747             -77.48                   -22.5        26081.05
# 22746             -77.48                   -22.5        26081.05
# 22745             -77.48                   -22.5        26081.05
# 141995            -57.02                   -14.8        12968.84
# 141996            -57.02                   -14.8        12968.84
# 141994            -57.02                   -14.8        12968.84
#
#         av_order_value  av_unique_items_per_order  favorite_store_id  \
# 22750        68.096736                   4.013055                196
# 22744        68.096736                   4.013055                196
# 22749        68.096736                   4.013055                196
# 22748        68.096736                   4.013055                196
# 22747        68.096736                   4.013055                196
# 22746        68.096736                   4.013055                196
# 22745        68.096736                   4.013055                196
# 141995       91.329859                  12.598592                107
# 141996       91.329859                  12.598592                107
# 141994       91.329859                  12.598592                107
#
#         timeperiod_day  timeperiod_evening  timeperiod_morning  \
# 22750             35.0               206.0                 1.0
# 22744             35.0               206.0                 1.0
# 22749             35.0               206.0                 1.0
# 22748             35.0               206.0                 1.0
# 22747             35.0               206.0                 1.0
# 22746             35.0               206.0                 1.0
# 22745             35.0               206.0                 1.0
# 141995             8.0                41.0                 4.0
# 141996             8.0                41.0                 4.0
# 141994             8.0                41.0                 4.0
#
#         timeperiod_night  orders_per_week  orders_per_day  items_per_user  \
# 22750              141.0         4.352273        1.268212     17744636782
# 22744              141.0         4.352273        1.268212     17744636782
# 22749              141.0         4.352273        1.268212     17744636782
# 22748              141.0         4.352273        1.268212     17744636782
# 22747              141.0         4.352273        1.268212     17744636782
# 22746              141.0         4.352273        1.268212     17744636782
# 22745              141.0         4.352273        1.268212     17744636782
# 141995              89.0         1.844156        1.100775     11783050050
# 141996              89.0         1.844156        1.100775     11783050050
# 141994              89.0         1.844156        1.100775     11783050050
#
#         av_items_per_order marital_status_code homeowner_desc  \
# 22750         4.633064e+07                   A      Homeowner
# 22744         4.633064e+07                   A      Homeowner
# 22749         4.633064e+07                   A      Homeowner
# 22748         4.633064e+07                   A      Homeowner
# 22747         4.633064e+07                   A      Homeowner
# 22746         4.633064e+07                   A      Homeowner
# 22745         4.633064e+07                   A      Homeowner
# 141995        8.297923e+07                   A      Homeowner
# 141996        8.297923e+07                   A      Homeowner
# 141994        8.297923e+07                   A      Homeowner
#
#         household_size_desc  kid_category_desc  income_desc_mean  \
# 22750                   NaN                NaN             133.0
# 22744                   NaN                NaN             133.0
# 22749                   NaN                NaN             133.0
# 22748                   NaN                NaN             133.0
# 22747                   NaN                NaN             133.0
# 22746                   NaN                NaN             133.0
# 22745                   NaN                NaN             133.0
# 141995                  NaN                NaN              63.0
# 141996                  NaN                NaN              63.0
# 141994                  NaN                NaN              63.0
#
#         age_desc_mean  unique_orders_per_item  amount_items  retail_disc_item  \
# 22750            50.0                 27362.0       28384.0          -1924.23
# 22744            50.0                 27362.0       28384.0          -1924.23
# 22749            50.0                 27362.0       28384.0          -1924.23
# 22748            50.0                 27362.0       28384.0          -1924.23
# 22747            50.0                 27362.0       28384.0          -1924.23
# 22746            50.0                 27362.0       28384.0          -1924.23
# 22745            50.0                 27362.0       28384.0          -1924.23
# 141995           40.0                 27362.0       28384.0          -1924.23
# 141996           40.0                 27362.0       28384.0          -1924.23
# 141994           40.0                 27362.0       28384.0          -1924.23
#
#         coupon_disc_item  coupon_match_disc_item  value_per_item  \
# 22750                0.0                     0.0        27291.02
# 22744                0.0                     0.0        27291.02
# 22749                0.0                     0.0        27291.02
# 22748                0.0                     0.0        27291.02
# 22747                0.0                     0.0        27291.02
# 22746                0.0                     0.0        27291.02
# 22745                0.0                     0.0        27291.02
# 141995               0.0                     0.0        27291.02
# 141996               0.0                     0.0        27291.02
# 141994               0.0                     0.0        27291.02
#
#         av_item_price  av_item_discount  manufacturer department  brand  \
# 22750        0.961493               0.0           2.0    PRODUCE    NaN
# 22744        0.961493               0.0           2.0    PRODUCE    NaN
# 22749        0.961493               0.0           2.0    PRODUCE    NaN
# 22748        0.961493               0.0           2.0    PRODUCE    NaN
# 22747        0.961493               0.0           2.0    PRODUCE    NaN
# 22746        0.961493               0.0           2.0    PRODUCE    NaN
# 22745        0.961493               0.0           2.0    PRODUCE    NaN
# 141995       0.961493               0.0           2.0    PRODUCE    NaN
# 141996       0.961493               0.0           2.0    PRODUCE    NaN
# 141994       0.961493               0.0           2.0    PRODUCE    NaN
#
#         commodity_desc sub_commodity_desc  items_per_department  \
# 22750   TROPICAL FRUIT            BANANAS                3118.0
# 22744   TROPICAL FRUIT            BANANAS                3118.0
# 22749   TROPICAL FRUIT            BANANAS                3118.0
# 22748   TROPICAL FRUIT            BANANAS                3118.0
# 22747   TROPICAL FRUIT            BANANAS                3118.0
# 22746   TROPICAL FRUIT            BANANAS                3118.0
# 22745   TROPICAL FRUIT            BANANAS                3118.0
# 141995  TROPICAL FRUIT            BANANAS                3118.0
# 141996  TROPICAL FRUIT            BANANAS                3118.0
# 141994  TROPICAL FRUIT            BANANAS                3118.0
#
#         items_per_commodity_desc  items_per_sub_commodity_desc         0  \
# 22750                       83.0                          17.0  0.043719
# 22744                       83.0                          17.0  0.043719
# 22749                       83.0                          17.0  0.043719
# 22748                       83.0                          17.0  0.043719
# 22747                       83.0                          17.0  0.043719
# 22746                       83.0                          17.0  0.043719
# 22745                       83.0                          17.0  0.043719
# 141995                      83.0                          17.0  0.045711
# 141996                      83.0                          17.0  0.045711
# 141994                      83.0                          17.0  0.045711
#
#                1
# 22750   0.956281
# 22744   0.956281
# 22749   0.956281
# 22748   0.956281
# 22747   0.956281
# 22746   0.956281
# 22745   0.956281
# 141995  0.954289
# 141996  0.954289
# 141994  0.954289

# %%
result2 = result.groupby(['user_id', 'item_id'], as_index=False).agg({1: 'max'}).rename(columns={1: 'proba'})
result2.sort_values(by=['proba'], ascending=False, inplace=True)
result2.drop('proba', axis=1, inplace=True)
result2.head(2)
# Out:
#         user_id  item_id
# 248240     1609  1082185
# 361401     2317  1082185

# %%
result2.shape
# Out:
# (389616, 2)

# %%
result_lvl_2 = result2.groupby('user_id', as_index=False).agg({'item_id': list}).rename(columns={'item_id': 'lightgbm_result'})
result_lvl_2.head()
# Out:
#    user_id                                    lightgbm_result
# 0        1  [1029743, 1106523, 8293439, 15926844, 1126899,...
# 1        3  [1029743, 1106523, 1126899, 1070820, 1110244, ...
# 2        6  [1082185, 1098844, 1029743, 1106523, 12757544,...
# 3        7  [1029743, 1106523, 1126899, 1070820, 866211, 1...
# 4        8  [1029743, 1106523, 1070820, 1126899, 916122, 6...

# %%
result_lvl_2.shape
# Out:
# (2042, 2)

# %%
result_lvl_2_actual = data_val_lvl_2.groupby('user_id')['item_id'].unique().reset_index()
result_lvl_2_actual.columns=['user_id', 'actual']
result_lvl_2_actual.head(2)
# Out:
#    user_id                                             actual
# 0        1  [821867, 834484, 856942, 865456, 889248, 90795...
# 1        3  [835476, 851057, 872021, 878302, 879948, 90963...

# %%
result_lvl_2 = result_lvl_2.merge(result_lvl_2_actual, on='user_id', how='left')
result_lvl_2.head(2)
# Out:
#    user_id                                    lightgbm_result  \
# 0        1  [1029743, 1106523, 8293439, 15926844, 1126899,...
# 1        3  [1029743, 1106523, 1126899, 1070820, 1110244, ...
#
#                                               actual
# 0  [821867, 834484, 856942, 865456, 889248, 90795...
# 1  [835476, 851057, 872021, 878302, 879948, 90963...

# %%
# %%time
print('precision_at_k', 'lightgbm_result',
      result_lvl_2.apply(lambda row: precision_at_k(row['lightgbm_result'], row['actual']), axis=1).mean())
# Out:
# precision_at_k lightgbm_result 0.1659157688540623
# Wall time: 165 ms

# %% [markdown]
# #### В двухуровневой моделе precision_at_k немного ниже, чем в моделе get_own_recommendations. Выше я измерил precision_at_k для get_own_recommendations = 0.17901578458681228
